# %% [markdown]
# # Bundle A.2: ストレス期 drawdown
#
# 詳細は [README.md](../README.md) を参照。本ノートブックは結果の表示用。
#
# **核心**: GFC で HY Size cum ret=+41%、COVID で HY 全因子プラス、2022 で軽傷。post-BBW 期でもファクタープレミアム未消失を実証。

# %%
from __future__ import annotations

from pathlib import Path

import pandas as pd
from IPython.display import Image, Markdown, display

PAPER_DIR = Path("..").resolve()
RESULTS = PAPER_DIR / "results"
SCRIPT = PAPER_DIR / "scripts" / "stress_drawdowns.py"

print(f"Paper dir: {PAPER_DIR}")
print(f"Results exists: {RESULTS.exists()}")
print(f"Script: {SCRIPT} exists: {SCRIPT.exists()}")
# Out:
# Paper dir: /home/tarai/Research/FI-research/projects/derivatives/a_robeco_credit_pc
# Results exists: True
# Script: /home/tarai/Research/FI-research/projects/derivatives/a_robeco_credit_pc/scripts/stress_drawdowns.py exists: True

# %% [markdown]
# ## (オプション) 再実行
#
# ```bash
# python projects/derivatives/a_robeco_credit_pc/scripts/stress_drawdowns.py
# ```

# %% [markdown]
# ## 結果テーブル

# %%
print('=' * 60)
print('Table: stress_drawdowns.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'stress_drawdowns.csv').head(40))
# Out:
# ...
# Table: stress_drawdowns.csv
# ...
#    market          stress               factor    max_dd   peak_date  \
# 0      IG   GFC_2007_2009                 Size -0.229305  2007-07-31
# 1      IG   GFC_2007_2009              LowRisk -0.102027  2007-07-31
# 2      IG   GFC_2007_2009                Value -0.373695  2007-07-31
# 3      IG   GFC_2007_2009             Momentum -0.186791  2007-07-31
# 4      IG   GFC_2007_2009          MultiFactor -0.217108  2007-07-31
# 5      IG   GFC_2007_2009  BENCH_BAA10Y_excess -0.264833  2007-07-31
# 6      IG      COVID_2020                 Size -0.098226  2020-02-29
# 7      IG      COVID_2020              LowRisk -0.021341  2020-02-29
# 8      IG      COVID_2020                Value -0.137550  2020-02-29
# 9      IG      COVID_2020             Momentum -0.145962  2020-02-29
# 10     IG      COVID_2020          MultiFactor -0.100770  2020-02-29
# 11     IG      COVID_2020  BENCH_BAA10Y_excess -0.108500  2020-02-29
# ...

# %% [markdown]
# ## 図

# %%
display(Markdown('### stress_cumret_IG.png'))
display(Image(str(RESULTS / 'stress_cumret_IG.png')))

display(Markdown('### stress_cumret_HY.png'))
display(Image(str(RESULTS / 'stress_cumret_HY.png')))

display(Markdown('### max_dd_heatmap.png'))
display(Image(str(RESULTS / 'max_dd_heatmap.png')))
# Out:
# ### stress_cumret_IG.png
# ### stress_cumret_HY.png
# ### max_dd_heatmap.png
