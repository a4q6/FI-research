# %% [markdown]
# # Bundle A.1: Robeco PC1 直交化
#
# 詳細は [README.md](../README.md) を参照。本ノートブックは結果の表示用。
#
# **核心**: BAA10Y proxy 直交化で HvZ 論文 Table 3 IR の 80-100% を回復。PC1 (endogenous) は内生性で IR を過大評価。

# %%
from __future__ import annotations

from pathlib import Path

import pandas as pd
from IPython.display import Image, Markdown, display

PAPER_DIR = Path("..").resolve()
RESULTS = PAPER_DIR / "results"
SCRIPT = PAPER_DIR / "scripts" / "credit_pc_orth.py"

print(f"Paper dir: {PAPER_DIR}")
print(f"Results exists: {RESULTS.exists()}")
print(f"Script: {SCRIPT} exists: {SCRIPT.exists()}")
# Out:
# Paper dir: /home/tarai/Research/FI-research/projects/derivatives/a_robeco_credit_pc
# Results exists: True
# Script: /home/tarai/Research/FI-research/projects/derivatives/a_robeco_credit_pc/scripts/credit_pc_orth.py exists: True

# %% [markdown]
# ## (オプション) 再実行
#
# ```bash
# python projects/derivatives/a_robeco_credit_pc/scripts/credit_pc_orth.py
# ```

# %% [markdown]
# ## 結果テーブル

# %%
print('=' * 60)
print('Table: all_stats.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'all_stats.csv').head(40))

print('=' * 60)
print('Table: exo_credit_orth_IG_paper_1994_2015.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'exo_credit_orth_IG_paper_1994_2015.csv').head(40))

print('=' * 60)
print('Table: exo_credit_orth_HY_paper_1994_2015.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'exo_credit_orth_HY_paper_1994_2015.csv').head(40))
# Out:
# ...
# Table: all_stats.csv
# ...
#    market           sample            kind           factor  mean_ann_pct  \
# 0      IG  paper_1994_2015             raw             Size      1.569164
# 1      IG  paper_1994_2015             raw          LowRisk      0.904018
# 2      IG  paper_1994_2015             raw            Value      1.629631
# 3      IG  paper_1994_2015             raw         Momentum      0.712156
# 4      IG  paper_1994_2015             raw  MultiFactor(EW)      1.203742
# 5      IG  paper_1994_2015  pc1_orth_alpha             Size           NaN
# 6      IG  paper_1994_2015  pc1_orth_alpha          LowRisk           NaN
# 7      IG  paper_1994_2015  pc1_orth_alpha            Value           NaN
# 8      IG  paper_1994_2015  pc1_orth_alpha         Momentum           NaN
# 9      IG  paper_1994_2015  pc1_orth_alpha  MultiFactor(EW)           NaN
# 10     IG   full_1994_2025             raw             Size      1.850481
# ...

# %% [markdown]
# ## 図

# %%
display(Markdown('### ir_4way_comparison.png'))
display(Image(str(RESULTS / 'ir_4way_comparison.png')))

display(Markdown('### cumret_orth_vs_raw.png'))
display(Image(str(RESULTS / 'cumret_orth_vs_raw.png')))
# Out:
# ### ir_4way_comparison.png
# ### cumret_orth_vs_raw.png
