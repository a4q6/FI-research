# %% [markdown]
# # Bundle B.2: regime 分解 (NBER × QE)
#
# 詳細は [README.md](../README.md) を参照。本ノートブックは結果の表示用。
#
# **核心**: EBP は QE active 期間で R²=0.51 と最強、平穏時 R²=0.04。崩壊は post-2011 ではなく「QE 終了後の calm 期」が正体。

# %%
from __future__ import annotations

from pathlib import Path

import pandas as pd
from IPython.display import Image, Markdown, display

PAPER_DIR = Path("..").resolve()
RESULTS = PAPER_DIR / "results"
SCRIPT = PAPER_DIR / "scripts" / "regime_decomposition.py"

print(f"Paper dir: {PAPER_DIR}")
print(f"Results exists: {RESULTS.exists()}")
print(f"Script: {SCRIPT} exists: {SCRIPT.exists()}")
# Out:
# Paper dir: /home/tarai/Research/FI-research/projects/derivatives/b_post_qe_structural
# Results exists: True
# Script: /home/tarai/Research/FI-research/projects/derivatives/b_post_qe_structural/scripts/regime_decomposition.py exists: True

# %% [markdown]
# ## (オプション) 再実行
#
# ```bash
# python projects/derivatives/b_post_qe_structural/scripts/regime_decomposition.py
# ```

# %% [markdown]
# ## 結果テーブル

# %%
print('=' * 60)
print('Table: regime_decomposition.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'regime_decomposition.csv').head(40))
# Out:
# ...
# Table: regime_decomposition.csv
# ...
#    stress       target  horizon       regime      coef          t        R2  \
# 0     ebp  dlog_payems        6          all -1.049029  -6.269852  0.134667
# 1     ebp  dlog_payems        6         NBER -0.928156  -8.362106  0.220429
# 2     ebp  dlog_payems        6       noNBER -0.483664  -2.148874  0.018315
# 3     ebp  dlog_payems        6           QE -1.254724 -13.952379  0.394947
# 4     ebp  dlog_payems        6         noQE -0.917806  -3.559823  0.073967
# 5     ebp  dlog_payems        6    NBER×noQE -1.365750  -4.193920  0.395859
# 6     ebp  dlog_payems        6    noNBER×QE -1.003081  -1.169174  0.075629
# 7     ebp  dlog_payems        6  noNBER×noQE -0.387099  -1.669927  0.011618
# 8     ebp  dlog_payems       12          all -1.778121  -6.858303  0.174455
# 9     ebp  dlog_payems       12         NBER -1.134542  -7.206450  0.151895
# 10    ebp  dlog_payems       12       noNBER -1.226218  -3.353035  0.054461
# ...

# %% [markdown]
# ## 図

# %%
display(Markdown('### regime_r2_bars.png'))
display(Image(str(RESULTS / 'regime_r2_bars.png')))
# Out:
# ### regime_r2_bars.png
