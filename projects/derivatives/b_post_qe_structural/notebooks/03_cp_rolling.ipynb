# %% [markdown]
# # Bundle B.3: CP factor rolling regression
#
# 詳細は [README.md](../README.md) を参照。本ノートブックは結果の表示用。
#
# **核心**: 10y rolling window で R² が 0.04 〜 0.91 まで変動。最大は 2007-2017 window、最小は 2014-2024。レジーム依存性を強く示唆。

# %%
from __future__ import annotations

from pathlib import Path

import pandas as pd
from IPython.display import Image, Markdown, display

PAPER_DIR = Path("..").resolve()
RESULTS = PAPER_DIR / "results"
SCRIPT = PAPER_DIR / "scripts" / "cp_rolling.py"

print(f"Paper dir: {PAPER_DIR}")
print(f"Results exists: {RESULTS.exists()}")
print(f"Script: {SCRIPT} exists: {SCRIPT.exists()}")
# Out:
# Paper dir: /home/tarai/Research/FI-research/projects/derivatives/b_post_qe_structural
# Results exists: True
# Script: /home/tarai/Research/FI-research/projects/derivatives/b_post_qe_structural/scripts/cp_rolling.py exists: True

# %% [markdown]
# ## (オプション) 再実行
#
# ```bash
# python projects/derivatives/b_post_qe_structural/scripts/cp_rolling.py
# ```

# %% [markdown]
# ## 結果テーブル

# %%
print('=' * 60)
print('Table: cp_rolling.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'cp_rolling.csv').head(40))
# Out:
# ...
# Table: cp_rolling.csv
# ...
#           date maturity        R2  n_obs   b_const      b_f1       b_f2  \
# 0   1971-06-30        2  0.577390    120 -0.016617 -2.779895  11.630259
# 1   1971-06-30        3  0.538859    120 -0.027984 -4.759195  18.981758
# 2   1971-06-30        4  0.510622    120 -0.038539 -6.277486  24.533902
# 3   1971-06-30        5  0.484826    120 -0.048962 -7.541634  29.083853
# 4   1971-06-30      avg  0.516599    120 -0.033026 -5.339553  21.057443
# 5   1971-07-31        2  0.584345    120 -0.016635 -2.720746  11.593868
# 6   1971-07-31        3  0.545254    120 -0.028023 -4.667602  18.930154
# 7   1971-07-31        4  0.517351    120 -0.038612 -6.177457  24.491690
# 8   1971-07-31        5  0.492344    120 -0.049098 -7.447229  29.074528
# 9   1971-07-31      avg  0.523619    120 -0.033092 -5.253258  21.022560
# 10  1971-08-31        2  0.591868    120 -0.016881 -2.756934  11.619011
# 11  1971-08-31        3  0.552044    120 -0.028296 -4.720705  18.966113
# ...

# %% [markdown]
# ## 図

# %%
display(Markdown('### cp_rolling_r2.png'))
display(Image(str(RESULTS / 'cp_rolling_r2.png')))

display(Markdown('### cp_rolling_coefs_rx5.png'))
display(Image(str(RESULTS / 'cp_rolling_coefs_rx5.png')))

display(Markdown('### cp_rolling_r2_with_recessions.png'))
display(Image(str(RESULTS / 'cp_rolling_r2_with_recessions.png')))
# Out:
# ### cp_rolling_r2.png
# ### cp_rolling_coefs_rx5.png
# ### cp_rolling_r2_with_recessions.png
