# %% [markdown]
# # Bundle B.1: stress index horse race
#
# 詳細は [README.md](../README.md) を参照。本ノートブックは結果の表示用。
#
# **核心**: pre-2011 で OFR FSI Credit の R²=0.72。post-2011 で 0.00。9 つ全ての stress index が一斉に崩壊 → 構造変化は EBP 特有ではない。

# %%
from __future__ import annotations

from pathlib import Path

import pandas as pd
from IPython.display import Image, Markdown, display

PAPER_DIR = Path("..").resolve()
RESULTS = PAPER_DIR / "results"
SCRIPT = PAPER_DIR / "scripts" / "ebp_horse_race.py"

print(f"Paper dir: {PAPER_DIR}")
print(f"Results exists: {RESULTS.exists()}")
print(f"Script: {SCRIPT} exists: {SCRIPT.exists()}")
# Out:
# Paper dir: /home/tarai/Research/FI-research/projects/derivatives/b_post_qe_structural
# Results exists: True
# Script: /home/tarai/Research/FI-research/projects/derivatives/b_post_qe_structural/scripts/ebp_horse_race.py exists: True

# %% [markdown]
# ## (オプション) 再実行
#
# ```bash
# python projects/derivatives/b_post_qe_structural/scripts/ebp_horse_race.py
# ```

# %% [markdown]
# ## 結果テーブル

# %%
print('=' * 60)
print('Table: horse_race_results.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'horse_race_results.csv').head(40))
# Out:
# ...
# Table: horse_race_results.csv
# ...
#       sample        target  horizon          stress      coef          t  \
# 0   pre_2011       Δlog IP        3             ebp -1.494749  -5.657430
# 1   pre_2011       Δlog IP        3            NFCI -0.818513  -5.489831
# 2   pre_2011       Δlog IP        3           ANFCI -0.891137  -6.122660
# 3   pre_2011       Δlog IP        3         STLFSI4 -0.890751  -7.175667
# 4   pre_2011       Δlog IP        3   ofr_fsi_total -0.224457  -5.446845
# 5   pre_2011       Δlog IP        3  ofr_fsi_credit -0.524719  -3.800602
# 6   pre_2011       Δlog IP        3      ofr_fsi_us -0.528547  -4.855457
# 7   pre_2011       Δlog IP        3            MOVE -0.029675  -2.780308
# 8   pre_2011       Δlog IP        3          VIXCLS -0.087781  -2.838215
# 9   pre_2011       Δlog IP        6             ebp -2.478867  -4.615606
# 10  pre_2011       Δlog IP        6            NFCI -1.518363  -5.461888
# ...

# %% [markdown]
# ## 図

# %%
display(Markdown('### horse_race_heatmap.png'))
display(Image(str(RESULTS / 'horse_race_heatmap.png')))

display(Markdown('### horse_race_bars_payroll12m.png'))
display(Image(str(RESULTS / 'horse_race_bars_payroll12m.png')))
# Out:
# ### horse_race_heatmap.png
# ### horse_race_bars_payroll12m.png
