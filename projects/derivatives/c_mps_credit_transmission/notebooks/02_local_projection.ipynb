# %% [markdown]
# # Bundle C.2: Jordà 2005 local projection
#
# 詳細は [README.md](../README.md) を参照。本ノートブックは結果の表示用。
#
# **核心**: BAA10Y は h=0 で narrowing → h=30 で widening (β=+0.96)。Treasury は h=2 でピーク後減衰。Gertler-Karadi credit channel の典型パターンを公開データで再現。

# %%
from __future__ import annotations

from pathlib import Path

import pandas as pd
from IPython.display import Image, Markdown, display

PAPER_DIR = Path("..").resolve()
RESULTS = PAPER_DIR / "results"
SCRIPT = PAPER_DIR / "scripts" / "local_projection.py"

print(f"Paper dir: {PAPER_DIR}")
print(f"Results exists: {RESULTS.exists()}")
print(f"Script: {SCRIPT} exists: {SCRIPT.exists()}")
# Out:
# Paper dir: /home/tarai/Research/FI-research/projects/derivatives/c_mps_credit_transmission
# Results exists: True
# Script: /home/tarai/Research/FI-research/projects/derivatives/c_mps_credit_transmission/scripts/local_projection.py exists: True

# %% [markdown]
# ## (オプション) 再実行
#
# ```bash
# python projects/derivatives/c_mps_credit_transmission/scripts/local_projection.py
# ```

# %% [markdown]
# ## 結果テーブル

# %%
print('=' * 60)
print('Table: local_projection_irfs.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'local_projection_irfs.csv').head(40))
# Out:
# ...
# Table: local_projection_irfs.csv
# ...
#     h_days      coef        se         t     ci_lo     ci_hi  n_obs  series  \
# 0        0 -0.200802  0.040015 -5.018141 -0.279232 -0.122372    309  BAA10Y
# 1        1 -0.155076  0.060643 -2.557183 -0.273936 -0.036215    309  BAA10Y
# 2        2 -0.043471  0.076420 -0.568842 -0.193255  0.106313    309  BAA10Y
# 3        3  0.024823  0.079647  0.311666 -0.131284  0.180930    309  BAA10Y
# 4        4  0.138261  0.098067  1.409860 -0.053951  0.330474    309  BAA10Y
# 5        5  0.155003  0.113288  1.368220 -0.067042  0.377049    309  BAA10Y
# 6        6  0.222791  0.142331  1.565300 -0.056178  0.501761    309  BAA10Y
# 7        7  0.299437  0.162210  1.845981 -0.018495  0.617370    309  BAA10Y
# 8        8  0.305100  0.175678  1.736695 -0.039230  0.649430    309  BAA10Y
# 9        9  0.320554  0.193068  1.660318 -0.057859  0.698968    309  BAA10Y
# 10      10  0.354785  0.207879  1.706688 -0.052658  0.762227    309  BAA10Y
# ...

# %% [markdown]
# ## 図

# %%
display(Markdown('### local_projection_irfs.png'))
display(Image(str(RESULTS / 'local_projection_irfs.png')))

display(Markdown('### irf_mps_orth_comparison.png'))
display(Image(str(RESULTS / 'irf_mps_orth_comparison.png')))
# Out:
# ### local_projection_irfs.png
# ### irf_mps_orth_comparison.png
