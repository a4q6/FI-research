# %% [markdown]
# # Bundle C.3: stress regime × MP shock interaction
#
# 詳細は [README.md](../README.md) を参照。本ノートブックは結果の表示用。
#
# **核心 (novel finding)**: MP 伝達が OFR FSI で完全に sign-reversed。Calm 期は引締め→ narrowing、Stress 期は引締め→ widening。Interaction t>6。

# %%
from __future__ import annotations

from pathlib import Path

import pandas as pd
from IPython.display import Image, Markdown, display

PAPER_DIR = Path("..").resolve()
RESULTS = PAPER_DIR / "results"
SCRIPT = PAPER_DIR / "scripts" / "regime_interaction.py"

print(f"Paper dir: {PAPER_DIR}")
print(f"Results exists: {RESULTS.exists()}")
print(f"Script: {SCRIPT} exists: {SCRIPT.exists()}")
# Out:
# Paper dir: /home/tarai/Research/FI-research/projects/derivatives/c_mps_credit_transmission
# Results exists: True
# Script: /home/tarai/Research/FI-research/projects/derivatives/c_mps_credit_transmission/scripts/regime_interaction.py exists: True

# %% [markdown]
# ## (オプション) 再実行
#
# ```bash
# python projects/derivatives/c_mps_credit_transmission/scripts/regime_interaction.py
# ```

# %% [markdown]
# ## 結果テーブル

# %%
print('=' * 60)
print('Table: regime_interaction.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'regime_interaction.csv').head(40))
# Out:
# ...
# Table: regime_interaction.csv
# ...
#             series  h_days    n  beta_mps_orth  beta_interaction  \
# 0           BAA10Y       1  193      -0.147935          0.007054
# 1           BAA10Y       5  193      -0.079280          0.058139
# 2           BAA10Y      10  193       0.078258          0.113519
# 3           BAA10Y      15  193       0.070096          0.172808
# 4           BAA10Y      20  193       0.156943          0.200691
# 5           BAA10Y      30  193       0.014250          0.272111
# 6           BAA10Y      40  193      -0.155495          0.273962
# 7           AAA10Y       1  193      -0.171223         -0.003491
# 8           AAA10Y       5  193      -0.108229          0.032336
# 9           AAA10Y      10  193       0.001724          0.050323
# 10          AAA10Y      15  193      -0.054450          0.051895
# 11          AAA10Y      20  193       0.029571          0.052913
# 12          AAA10Y      30  193      -0.035603          0.082178
# ...

# %% [markdown]
# ## 図

# %%
display(Markdown('### regime_interaction_irfs.png'))
display(Image(str(RESULTS / 'regime_interaction_irfs.png')))
# Out:
# ### regime_interaction_irfs.png
