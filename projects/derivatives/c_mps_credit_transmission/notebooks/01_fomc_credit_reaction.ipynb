# %% [markdown]
# # Bundle C.1: FOMC 日のクレジット反応
#
# 詳細は [README.md](../README.md) を参照。本ノートブックは結果の表示用。
#
# **核心**: 1 日 window で contractionary mps_orth → BAA10Y β=-0.21 (t=-5.6)。narrowing は curve mechanical 効果。BAA-AAA risk premium は 1 日では反応せず。

# %%
from __future__ import annotations

from pathlib import Path

import pandas as pd
from IPython.display import Image, Markdown, display

PAPER_DIR = Path("..").resolve()
RESULTS = PAPER_DIR / "results"
SCRIPT = PAPER_DIR / "scripts" / "baml_oas_fomc_reaction.py"

print(f"Paper dir: {PAPER_DIR}")
print(f"Results exists: {RESULTS.exists()}")
print(f"Script: {SCRIPT} exists: {SCRIPT.exists()}")
# Out:
# Paper dir: /home/tarai/Research/FI-research/projects/derivatives/c_mps_credit_transmission
# Results exists: True
# Script: /home/tarai/Research/FI-research/projects/derivatives/c_mps_credit_transmission/scripts/baml_oas_fomc_reaction.py exists: True

# %% [markdown]
# ## (オプション) 再実行
#
# ```bash
# python projects/derivatives/c_mps_credit_transmission/scripts/baml_oas_fomc_reaction.py
# ```

# %% [markdown]
# ## 結果テーブル

# %%
print('=' * 60)
print('Table: fomc_credit_reactions.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'fomc_credit_reactions.csv').head(40))
# Out:
# ...
# Table: fomc_credit_reactions.csv
# ...
#             series     shock      coef        se         t        R2  n_obs  \
# 0           BAA10Y       mps -0.212452  0.034289 -6.195840  0.091804    332
# 1           BAA10Y  mps_orth -0.209392  0.037374 -5.602619  0.074599    332
# 2           AAA10Y       mps -0.192836  0.037003 -5.211402  0.066747    332
# 3           AAA10Y  mps_orth -0.197253  0.040068 -4.922958  0.058422    332
# 4   BAA_AAA_spread       mps -0.019616  0.018355 -1.068694  0.002758    332
# 5   BAA_AAA_spread  mps_orth -0.012139  0.018911 -0.641905  0.000883    332
# 6           BAA10Y       mps -0.207653  0.034966 -5.938774  0.083637    369
# 7           BAA10Y  mps_orth -0.199419  0.037881 -5.264342  0.066567    357
# 8           AAA10Y       mps -0.184616  0.035944 -5.136271  0.052197    369
# 9           AAA10Y  mps_orth -0.189068  0.039167 -4.827180  0.053731    357
# 10  BAA_AAA_spread       mps -0.023037  0.019884 -1.158532  0.001637    369
# ...

# %% [markdown]
# ## 図

# %%
display(Markdown('### baa10y_fomc_scatter.png'))
display(Image(str(RESULTS / 'baa10y_fomc_scatter.png')))

display(Markdown('### credit_coefficients.png'))
display(Image(str(RESULTS / 'credit_coefficients.png')))
# Out:
# ### baa10y_fomc_scatter.png
# ### credit_coefficients.png
