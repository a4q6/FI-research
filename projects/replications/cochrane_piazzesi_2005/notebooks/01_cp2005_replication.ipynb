# %% [markdown]
# # Cochrane & Piazzesi (2005) 再現
#
# > Cochrane, J. H., & Piazzesi, M. (2005). Bond Risk Premia. *AER*, 95(1), 138-160.
#
# 詳細は [README.md](../README.md) を参照。本ノートブックは結果の表示用。
#
# **核心**: 単一ファクター制約 `unrestricted R² ≈ single-factor R²` が全サンプル・全満期で成立。論文の主要結論は再現できた一方、絶対 R² は GSW vs Fama-Bliss の手法差で論文より 10pt 低い。

# %%
from __future__ import annotations

from pathlib import Path

import pandas as pd
from IPython.display import Image, Markdown, display

# Repository-relative paths
PAPER_DIR = Path.cwd() if (Path.cwd().name == "cochrane_piazzesi_2005") else Path("..").resolve()
RESULTS = PAPER_DIR / "results"
SCRIPT = PAPER_DIR / "scripts" / "replicate.py"

# Sanity check
print(f"Paper dir: {PAPER_DIR}")
print(f"Results dir exists: {RESULTS.exists()}")
print(f"Script: {SCRIPT} exists: {SCRIPT.exists()}")
# Out:
# Paper dir: /home/tarai/Research/FI-research/projects/replications/cochrane_piazzesi_2005
# Results dir exists: True
# Script: /home/tarai/Research/FI-research/projects/replications/cochrane_piazzesi_2005/scripts/replicate.py exists: True

# %% [markdown]
# ## (オプション) 再実行
#
# 未実行 or データ更新後に走らせる。既存結果があればスキップしてよい。
#
# ```bash
# python projects/replications/cochrane_piazzesi_2005/scripts/replicate.py
# ```

# %% [markdown]
# ## 結果テーブル

# %%
print('=' * 60)
print('Table: r2_summary.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'r2_summary.csv'))
# Out:
# ...
# Table: r2_summary.csv
# ...
#                   sample             model maturity        R2  n_obs
# 0     cp_paper_1964_2003      unrestricted        2  0.203470    480
# 1     cp_paper_1964_2003      unrestricted        3  0.226778    480
# 2     cp_paper_1964_2003      unrestricted        4  0.244945    480
# 3     cp_paper_1964_2003      unrestricted        5  0.257992    480
# 4     cp_paper_1964_2003      unrestricted      avg  0.242140    480
# 5     cp_paper_1964_2003  cp_single_factor        2  0.199356    480
# 6     cp_paper_1964_2003  cp_single_factor        3  0.226257    480
# 7     cp_paper_1964_2003  cp_single_factor        4  0.244887    480
# 8     cp_paper_1964_2003  cp_single_factor        5  0.257198    480
# 9     cp_paper_1964_2003  cp_single_factor      avg  0.242140    480
# 10  post_paper_2004_2025      unrestricted        2  0.189254    257
# 11  post_paper_2004_2025      unrestricted        3  0.200317    257
# ...

# %% [markdown]
# ## 図

# %%
display(Markdown('### tent_shape_cp_paper_1964_2003.png'))
display(Image(str(RESULTS / 'tent_shape_cp_paper_1964_2003.png')))

display(Markdown('### tent_shape_full_1971_2025.png'))
display(Image(str(RESULTS / 'tent_shape_full_1971_2025.png')))
# Out:
# ### tent_shape_cp_paper_1964_2003.png
# ### tent_shape_full_1971_2025.png
