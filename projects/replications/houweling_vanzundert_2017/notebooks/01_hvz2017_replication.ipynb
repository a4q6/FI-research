# %% [markdown]
# # Houweling & van Zundert (2017) 再現
#
# > Houweling, P., & van Zundert, J. (2017). Factor Investing in the Corporate Bond Market. *FAJ*, 73(2), 100-115.
#
# 詳細は [README.md](../README.md) を参照。本ノートブックは結果の表示用。
#
# **核心**: IG / HY ともに Size / Low-Risk / Value / Momentum すべてで 正の超過リターン。フルサンプル 1994-2025 では HY 全ファクターの t-stat が 2.7 以上で有意 → **post-BBW でも社債ファクタープレミアムは消失していない**。

# %%
from __future__ import annotations

from pathlib import Path

import pandas as pd
from IPython.display import Image, Markdown, display

# Repository-relative paths
PAPER_DIR = Path.cwd() if (Path.cwd().name == "houweling_vanzundert_2017") else Path("..").resolve()
RESULTS = PAPER_DIR / "results"
SCRIPT = PAPER_DIR / "scripts" / "replicate.py"

# Sanity check
print(f"Paper dir: {PAPER_DIR}")
print(f"Results dir exists: {RESULTS.exists()}")
print(f"Script: {SCRIPT} exists: {SCRIPT.exists()}")
# Out:
# Paper dir: /home/tarai/Research/FI-research/projects/replications/houweling_vanzundert_2017
# Results dir exists: True
# Script: /home/tarai/Research/FI-research/projects/replications/houweling_vanzundert_2017/scripts/replicate.py exists: True

# %% [markdown]
# ## (オプション) 再実行
#
# 未実行 or データ更新後に走らせる。既存結果があればスキップしてよい。
#
# ```bash
# python projects/replications/houweling_vanzundert_2017/scripts/replicate.py
# ```

# %% [markdown]
# ## 結果テーブル

# %%
print('=' * 60)
print('Table: table3_IG_paper_1994_2015.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'table3_IG_paper_1994_2015.csv'))

print('=' * 60)
print('Table: table3_HY_paper_1994_2015.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'table3_HY_paper_1994_2015.csv'))

print('=' * 60)
print('Table: table3_IG_full_1994_2025.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'table3_IG_full_1994_2025.csv'))

print('=' * 60)
print('Table: table3_HY_full_1994_2025.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'table3_HY_full_1994_2025.csv'))

print('=' * 60)
print('Table: corr_IG_full.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'corr_IG_full.csv'))

print('=' * 60)
print('Table: corr_HY_full.csv')
print('=' * 60)
display(pd.read_csv(RESULTS / 'corr_HY_full.csv'))
# Out:
# ...
# Table: table3_IG_paper_1994_2015.csv
# ...
#     Unnamed: 0  mean_ann   vol_ann        IR    t_stat  n_months
# 0         Size  0.015692  0.038016  0.412760  1.924983     261.0
# 1      LowRisk  0.009040  0.022272  0.405899  1.892988     261.0
# 2        Value  0.016296  0.067382  0.241848  1.127904     261.0
# 3     Momentum  0.007122  0.043050  0.165425  0.771491     261.0
# 4  MultiFactor  0.012037  0.039665  0.303474  1.415308     261.0
# ...
# Table: table3_HY_paper_1994_2015.csv
# ...
#     Unnamed: 0  mean_ann   vol_ann        IR    t_stat  n_months
# 0         Size  0.074840  0.121633  0.615295  2.869545     261.0
# 1      LowRisk  0.036078  0.066728  0.540673  2.521532     261.0
# 2        Value  0.058376  0.134476  0.434104  2.024525     261.0
# 3     Momentum  0.040626  0.102612  0.395918  1.846439     261.0
# 4  MultiFactor  0.052480  0.100369  0.522871  2.438507     261.0
# ...
# Table: table3_IG_full_1994_2025.csv
# ...
#     Unnamed: 0  mean_ann   vol_ann        IR    t_stat  n_months
# ...

# %% [markdown]
# ## 図

# %%
display(Markdown('### cumret_IG.png'))
display(Image(str(RESULTS / 'cumret_IG.png')))

display(Markdown('### cumret_HY.png'))
display(Image(str(RESULTS / 'cumret_HY.png')))
# Out:
# ### cumret_IG.png
# ### cumret_HY.png
